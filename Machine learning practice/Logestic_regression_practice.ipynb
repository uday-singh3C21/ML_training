# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('HR_comma_sep.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df_encoded = pd.get_dummies(df, columns=['salary'], drop_first=True)

# %%
df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
subdf.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low

# %%
x = df_encoded[['satisfaction_level', 'average_montly_hours', 'promotion_last_5years', 
                'salary_medium', 'salary_high']]  # Adjust column names as needed

y = df_encoded['left']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 x = df_encoded[['satisfaction_level', 'average_montly_hours', 'promotion_last_5years',
#       2                 'salary_medium', 'salary_high']]  # Adjust column names as needed
#       4 y = df_encoded['left']
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/wp/l1lbtpb57rl387801fcn64ch0000gn/T/ipykernel_13167/1823912255.py in ?()
#       1 model = LogisticRegression()
# ----> 2 model.fit(X_train,Y_train)
#
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py in ?(self, X, y, sample_weight)
#    1197             _dtype = np.float64
#    1198         else:
#    1199             _dtype = [np.float64, np.float32]
#    1200
# -> 1201         X, y = self._validate_data(
#    1202             X,
# ...
