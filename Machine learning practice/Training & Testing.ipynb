# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('carprices.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
plt.scatter(data=df,x='Mileage',y='Age(yrs)')

# %%
plt.scatter(data=df,y='Sell Price($)',x='Age(yrs)')

# %%
x=df[['Mileage','Age(yrs)']]
y=df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 2     57000         5
# 6     52000         5
# 7     72000         6
# 15    25400         3
# 12    59000         5
# 11    79000         7
# 19    52000         5
# 10    83000         7
# 0     69000         6
# 13    58780         4
# 9     67000         6
# 17    69000         5
# 1     35000         3
# 3     22500         2
# 5     59000         5
# 18    87600         8

# %%
Y_test
# Out:
# 4     31500
# 14    19400
# 8     12000
# 16    35500
# Name: Sell Price($), dtype: int64

# %%
from sklearn import linear_model

# %%
clf =linear_model.LinearRegression()
clf.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([30315.7781127 , 16649.2453277 , 13305.09408459, 37306.92052022])

# %%
clf.score(X_test,Y_test)
# Out:
# 0.9604302280348137
